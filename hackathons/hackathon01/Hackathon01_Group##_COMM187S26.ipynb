# %% [markdown]
# # COMM 187: Data Science in Communication Research, Spring 2026
# ## Hackathon #1
#
# **Date:** Thursday, April 30, 2026 \
# **Time duration:** 1 hour \
# **Maximum points:** 10
#
# <span style="color:red">Follow the instruction sheet provided to you by the instructors.</span>

# %% [markdown]
# ### GROUP [number]: [Name of group]
#
# **Members**:
#  - Full name 1
#  - Full name 2
#  - Full name 3
#
# **Question Set:** A, B, C, or D?

# %% [markdown]
# ### Loading data (1 point)

# %%
## Write your code below this line

# %% [markdown]
# ### Q1 (3 points)

# %%
## Write your code below this line, and make new cells as needed

# %% [markdown]
# ### Q2 (3 points)

# %%
## Write your code below this line, and make new cells as needed

# %% [markdown]
# ### Q3 (2 points)

# %% [markdown]
# Replace this text with your answer.
